# %%
import re

# %%
def chatbot (input_test) :
  rules = {
      'name' : 'my name is Hope, how we can help you ?',
      'role' : 'my role is to unser your questions ! if I can, and if I can\'t, please don\'t be sade ): ',
      'how are you ?' : 'I am soo good, thank you for asking ! and you ?',
      'I am fine ' : 'that is great, please keep you like that !',
      'hello' : 'Hello sir/Mme, Could you let me know how I can help you today ? :)',
      'issue': 'Could you send us your Order ID please ?',
      'I can\'t find my order id sir ' : 'you will find it on your paypal receipt it will begin with these caracters #013... ',
      'what should I do now ?': ' could you rstart your device and check it now please ! ',
      'it is working ' : 'Thank you for letting us know sir, enjoy our service!',
      'are you a robot ?' :'No sir/Mme , I am human who talking with you now, and my name is Hope ',
      'default': 'I am sorry I did not get your question, could you rephrase it please !'
  }

  for rule, response in rules.items() :
    pattern = re.compile(rule,re.IGNORECASE)
    if re.search(pattern,input_test) :
      return response
      break
    else :
      return (rules['default'])

# %%
# test de chatbot function :
while True :
 input_test = input("you : ")
 if input_test.lower() == 'exit':
    print('chatbot : GoodBye :)')
    break
 response = chatbot(input_test)
 print('chatbot: ',str(response))
 break
# Out:
# you : name
# chatbot:  my name is Hope, how we can help you ?
